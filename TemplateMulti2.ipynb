# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import imutils

# %%
train_image = cv2.imread('../customimages/arrow18.jpg')

train_image = cv2.cvtColor(train_image, cv2.COLOR_BGR2RGB)

fig = plt.figure(figsize=(12,12))
ax  =fig.add_subplot(111)
ax.imshow(train_image)

# %% [markdown]
# test_image = cv2.imread('../customimages/arrow12.jpg')
# # test_image = cv2.resize(test_image, )
# test_image = imutils.resize(test_image, width = 800)
# # test_image = cv2.resize(test_image, (800,600))
# test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
#
# fig = plt.figure(figsize=(15,15))
# ax = fig.add_subplot(111)
# ax.imshow(test_image)
#
# kernel = np.ones((3,3),np.uint8)
# gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
# blur = cv2.GaussianBlur(gray,(3,3),0)
# ret3,gray = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# opening = cv2.morphologyEx(gray, cv2.MORPH_OPEN,kernel=kernel)
# opening = cv2.morphologyEx(opening, cv2.MORPH_CLOSE,kernel=kernel)
# gray = opening
# test_image = gray
# fig = plt.figure(figsize=(15,15))
# ax = fig.add_subplot(111)
# ax.imshow(test_image)

# %% [markdown]
# orb = cv2.xfeatures2d.SIFT_create()
#
# kp1, des1 = orb.detectAndCompute(train_image, None)
# kp2, des2 = orb.detectAndCompute(test_image, None)

# %% [markdown]
# bf = cv2.BFMatcher()
# matches = bf.knnMatch(des1, des2, k =2)
#
# good = []
# for m, n in matches:
#     if m.distance < 0.99*n.distance:
#         good.append([m])
#
# img3 = cv2.drawMatchesKnn(train_image, kp1, test_image, kp2, good[:], None, flags=2)
#
# fig = plt.figure(figsize=(15,15))
# ax = fig.add_subplot(111)
# ax.imshow(img3)
# plt.show()

# %%
import glob
for imagePath in glob.glob("../customimages/*.jpg"):
    test_image = cv2.imread(imagePath)
    # test_image = cv2.resize(test_image, )
    test_image = imutils.resize(test_image, width = 2000)
    # test_image = cv2.resize(test_image, (800,600))
    test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(test_image)

    kernel = np.ones((3,3),np.uint8)
    gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
    # blur = cv2.GaussianBlur(gray,(3,3),0)
    # blur = gray
    # ret3,gray = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    # opening = cv2.morphologyEx(gray, cv2.MORPH_OPEN,kernel=kernel)
    # opening = cv2.morphologyEx(opening, cv2.MORPH_CLOSE,kernel=kernel)
    # gray = opening
    # gray = cv2.threshold(test_image,)
    test_image = gray
    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(test_image)

    orb = cv2.xfeatures2d.SIFT_create()

    kp1, des1 = orb.detectAndCompute(train_image, None)
    kp2, des2 = orb.detectAndCompute(test_image, None)

    bf = cv2.BFMatcher()
    matches = bf.knnMatch(des1, des2, k =2)

    good = []
    for m, n in matches:
        if m.distance < 0.7*n.distance:
            good.append([m])

    img3 = cv2.drawMatchesKnn(train_image, kp1, test_image, kp2, good[:], None, flags=2)

    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(img3)
    plt.show()

# %%
import glob
for imagePath in glob.glob("../customimages/*.jpg"):
    test_image = cv2.imread(imagePath)
    # test_image = cv2.resize(test_image, )
    test_image = imutils.resize(test_image, width = 2000)
    # test_image = cv2.resize(test_image, (800,600))
    test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(test_image)

    kernel = np.ones((3,3),np.uint8)
    gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
    # blur = cv2.GaussianBlur(gray,(3,3),0)
    # blur = gray
    # ret3,gray = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    # opening = cv2.morphologyEx(gray, cv2.MORPH_OPEN,kernel=kernel)
    # opening = cv2.morphologyEx(opening, cv2.MORPH_CLOSE,kernel=kernel)
    # gray = opening
    # gray = cv2.threshold(test_image,)
    test_image = gray
    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(test_image)

    orb = cv2.AKAZE_create()

    kp1, des1 = orb.detectAndCompute(train_image, None)
    kp2, des2 = orb.detectAndCompute(test_image, None)

    bf = cv2.BFMatcher()
    matches = bf.knnMatch(des1, des2, k =2)

    good = []
    for m, n in matches:
        if m.distance < 0.7*n.distance:
            good.append([m])

    img3 = cv2.drawMatchesKnn(train_image, kp1, test_image, kp2, good[:], None, flags=2)

    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(img3)
    plt.show()

# %%
import glob
for imagePath in glob.glob("../customimages/*.jpg"):
    test_image = cv2.imread(imagePath)
    # test_image = cv2.resize(test_image, )
    test_image = imutils.resize(test_image, width = 2000)
    # test_image = cv2.resize(test_image, (800,600))
    test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(test_image)

    kernel = np.ones((3,3),np.uint8)
    gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
    # blur = cv2.GaussianBlur(gray,(3,3),0)
    # blur = gray
    # ret3,gray = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    # opening = cv2.morphologyEx(gray, cv2.MORPH_OPEN,kernel=kernel)
    # opening = cv2.morphologyEx(opening, cv2.MORPH_CLOSE,kernel=kernel)
    # gray = opening
    # gray = cv2.threshold(test_image,)
    test_image = gray
    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(test_image)

    orb = cv2.KAZE_create()

    kp1, des1 = orb.detectAndCompute(train_image, None)
    kp2, des2 = orb.detectAndCompute(test_image, None)

    bf = cv2.BFMatcher()
    matches = bf.knnMatch(des1, des2, k =2)

    good = []
    for m, n in matches:
        if m.distance < 0.7*n.distance:
            good.append([m])

    img3 = cv2.drawMatchesKnn(train_image, kp1, test_image, kp2, good[:], None, flags=2)

    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(img3)
    plt.show()

# %%
import glob
for imagePath in glob.glob("../customimages/*.jpg"):
    test_image = cv2.imread(imagePath)
    # test_image = cv2.resize(test_image, )
    test_image = imutils.resize(test_image, width = 2000)
    # test_image = cv2.resize(test_image, (800,600))
    test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(test_image)

    kernel = np.ones((3,3),np.uint8)
    gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
    # blur = cv2.GaussianBlur(gray,(3,3),0)
    # blur = gray
    # ret3,gray = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    # opening = cv2.morphologyEx(gray, cv2.MORPH_OPEN,kernel=kernel)
    # opening = cv2.morphologyEx(opening, cv2.MORPH_CLOSE,kernel=kernel)
    # gray = opening
    # gray = cv2.threshold(test_image,)
    test_image = gray
    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(test_image)

    orb = cv2.xfeatures2d.ASIFT_create()

    kp1, des1 = orb.detectAndCompute(train_image, None)
    kp2, des2 = orb.detectAndCompute(test_image, None)

    bf = cv2.BFMatcher()
    matches = bf.knnMatch(des1, des2, k =2)

    good = []
    for m, n in matches:
        if m.distance < 0.7*n.distance:
            good.append([m])

    img3 = cv2.drawMatchesKnn(train_image, kp1, test_image, kp2, good[:], None, flags=2)

    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(img3)
    plt.show()

# %%
import glob
for imagePath in glob.glob("../customimages/*.jpg"):
    test_image = cv2.imread(imagePath)
    # test_image = cv2.resize(test_image, )
    test_image = imutils.resize(test_image, width = 2000)
    # test_image = cv2.resize(test_image, (800,600))
    test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(test_image)

    kernel = np.ones((3,3),np.uint8)
    gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
    # blur = cv2.GaussianBlur(gray,(3,3),0)
    # blur = gray
    # ret3,gray = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    # opening = cv2.morphologyEx(gray, cv2.MORPH_OPEN,kernel=kernel)
    # opening = cv2.morphologyEx(opening, cv2.MORPH_CLOSE,kernel=kernel)
    # gray = opening
    # gray = cv2.threshold(test_image,)
    test_image = gray
    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(test_image)

    orb = cv2.xfeatures2d.SIFT_create()

    kp1, des1 = orb.detectAndCompute(train_image, None)
    kp2, des2 = orb.detectAndCompute(test_image, None)

    bf = cv2.BFMatcher()
    matches = bf.knnMatch(des1, des2, k =2)

    good = []
    for m, n in matches:
        if m.distance < 0.7*n.distance:
            good.append([m])

    img3 = cv2.drawMatchesKnn(train_image, kp1, test_image, kp2, good[:], None, flags=2)

    fig = plt.figure(figsize=(4,4))
    ax = fig.add_subplot(111)
    ax.imshow(img3)
    plt.show()
